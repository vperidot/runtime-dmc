# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
from IPython.display import Image
import os
import glob
plt.style.use('seaborn')

# %%
results = glob.glob('out/run_*/metrics_*.csv')

# %%
regr_buffer = 10

def regr_slope(z):
    x = np.array(range(0, len(z)))
    y = z
    x_std = x.std()
    y_std = y.std()
    (r,_) = stats.pearsonr(x, y)
    return r * (y_std/x_std)

# %%
for r in results:
    
    # grab info
    location, filename = os.path.split(r)
    df = pd.read_csv(r)
    
    #calculations
    df['KLSlope'] = df['KLDivergence'].rolling(regr_buffer).apply(lambda z: regr_slope(z))
    df['RevKLSlope'] = df['RevKLDivergence'].rolling(regr_buffer).apply(lambda z: regr_slope(z))
    
    # plot...
    fig = plt.figure(figsize=(20,25))
    
    # losses
    ax = plt.subplot(3,1,1)
    plt.title(filename)
    ax.plot(df['# GLoss'], label='Generator Loss')
    ax.plot(df['DLoss'], label='Discriminator Loss')
    plt.legend()
    # metrics
    ax2 = plt.subplot(3,1,2)
    ax2.plot(df['KLDivergence'], label='KL Divergence')
    ax2.plot(df['RevKLDivergence'], label='Reverse KL')
    plt.legend()
    # slopes of metrics
    ax3 = plt.subplot(3,1,3)
    df['KLSlope_log_relu'] = np.log(df['KLSlope'].clip(lower=0.0001).values)
    ax3.plot(df['KLSlope'], label='Slope of KL')
    ax3.plot(df['RevKLSlope'], label='Slope of Reverse KL')
    print(df[ df['RevKLSlope'] > 0.1 ].head(1))
    #plt.xscale('log')
    plt.legend()
    
    plt.show()
    
    print(location)
    Image(filename = (location + '/499.png'))
# Out:
#      # GLoss   DLoss  KLDivergence  RevKLDivergence   KLSlope  RevKLSlope  \
# 187  0.28555  2.6831        1.3925           2.8344  0.025306    0.135856
#
#      KLSlope_log_relu
# 187         -3.676711
# out\run_1
#      # GLoss   DLoss  KLDivergence  RevKLDivergence   KLSlope  RevKLSlope  \
# 173  0.37494  3.6012        1.2082           2.7007  0.022802    0.101978
#
#      KLSlope_log_relu
# 173         -3.780904
# out\run_2
#     # GLoss   DLoss  KLDivergence  RevKLDivergence   KLSlope  RevKLSlope  \
# 9  0.085499  8.1434        2.2986           7.1227  0.113577    0.544015
#
#    KLSlope_log_relu
# 9          -2.17527
# out\run_3
#      # GLoss   DLoss  KLDivergence  RevKLDivergence   KLSlope  RevKLSlope  \
# 361  0.35472  3.2588        1.3254            3.278  0.011498     0.10582
#
#      KLSlope_log_relu
# 361         -4.465566
# out\run_4
#      # GLoss   DLoss  KLDivergence  RevKLDivergence   KLSlope  RevKLSlope  \
# 253  0.31085  2.9363        1.3968           2.8271  0.027412    0.108535
#
#      KLSlope_log_relu
# 253         -3.596792
# out\run_5
#     # GLoss  DLoss  KLDivergence  RevKLDivergence   KLSlope  RevKLSlope  \
# 9  0.066075  5.506        2.3009           7.7741  0.126805     0.69586
#
#    KLSlope_log_relu
# 9         -2.065106
# out\run_6
# Empty DataFrame
# Columns: [# GLoss, DLoss, KLDivergence, RevKLDivergence, KLSlope, RevKLSlope, KLSlope_log_relu]
# Index: []
# out\run_7
# Empty DataFrame
# Columns: [# GLoss, DLoss, KLDivergence, RevKLDivergence, KLSlope, RevKLSlope, KLSlope_log_relu]
# Index: []
# out\run_8
# Empty DataFrame
# Columns: [# GLoss, DLoss, KLDivergence, RevKLDivergence, KLSlope, RevKLSlope, KLSlope_log_relu]
# Index: []
# out\run_9
